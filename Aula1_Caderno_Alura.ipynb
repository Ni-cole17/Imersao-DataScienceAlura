# %% [markdown]
# <a href="https://colab.research.google.com/github/Ni-cole17/Imersao-DataScienceAlura/blob/main/Aula1_Caderno_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para podermos importar um valor de um csv, é preciso importar a biblioteca pandas, após isso é necessário criar uma variável que receba esses valores.

# %%
import pandas as pd
dados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true',compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# dados.shape <-- utilizado para saber o tamanho do conjunto de dados (linhas,colunas)

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# dados['nome_da_coluna'].unique() <-- Permite verificar quais os valores que aparecem ao longo da coluna.

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# dados['nome_da_coluna'].value_counts() <-- Retorna a quantidade de elementos em cada possível valor da minha coluna

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts(normalize = True).plot.pie()

# %% [markdown]
# Não é interessante utilizar o gráfico de pizza para analisar os dados que estão muito próximos, ou melhor, que estão balanceados, por isso pode-se utilizar outros tipos de gráfico, como o de barra.

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]

# %%
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Aula 1
# ###**Desafio 1: Investigar por que a classe tratamento é tão desbalanceada?**
# ###**Desafio 2: Plotar as 5 últimas linhas da tabela.**
# ###**Desafio 3: Proporção das classes tratamento.**
# ###**Desafio 4: Quantos tipos de drogas foram investigados.**
# ###**Desafio 5: Procurar na documentação o método query (pandas).**
# ###**Desafio 6: Renomear as colunas tirando o hífen.**
# ###**Desafio 7: Deixar os gráficos bonito. (Com matplotlib)**
# ###**Desafio 8: Resumo do que você aprendeu com os dados**
# ##Aula 2
#
# ###**Desafio 1: Ordenar o gráfico countplot e plotar os outros gráficos com o countplot**
# ###**Desafio 2: Melhorar a visualização, alterando o tamanho da fonte, traduzir alguns elementos.**
# ###**Desafio 3: Plotar os histogramas com seaborn**
# ###**Desafio 4: Estudar sobre as estatísticas retornadas no .describe.**
# ###**Desafio 5: Refletir sobre a manipulação dos tamanhos das vizualizações**
# ###**Desafio 6: Plotar outros boxplots e histogramas para fazer outras análises**
# ###**Desafio 7: Resumo**
# ##Aula 3
#
# ###**Desafio 1: Criar tabelas de frequencia com o pandas.groupby()**
#
# ###**Desafio 2: Normalizar a tabela feita com o crosstab pela coluna**
#
# ###**Desafio 3: Explorar outros agregadores.**
#
# ###**Desafio 4: Explorar o melt.**
#
# ###**Desafio 5: Calcular e analisar a correlação entre o g e c da base de dados**
#
# ###**Desafio 6: Estudar o código para plotar o heatmap**
#
# ###**Desafio 7: Resumo**

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
import seaborn as sns

sns.countplot(x = 'composto',data=dados)

# %%
compostos = dados['composto'].value_counts().index[0:5]

# %%
compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @compostos'))
ax.set_title("Top 5 Compostos")
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
dados['g-19'].hist(bins=100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0','g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
descricao = dados.loc[0:,'g-0':'g-771'].describe()
descricao
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
descricao.T
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
descricao.T['mean'].hist(bins=30)

# %%
descricao.T['min'].hist(bins=30)

# %%
descricao.T['max'].hist(bins=30)

# %%
c = dados.loc[0:,'c-0':'c-99'].describe()
c
# Out:
#                 c-0           c-1  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      -0.355156     -0.455359  ...     -0.470252     -0.301505
# std        1.752565      2.004962  ...      1.834828      1.407918
# min      -10.000000    -10.000000  ...    -10.000000    -10.000000
# 25%       -0.549300     -0.538425  ...     -0.592600     -0.562900
# 50%       -0.009000      0.009800  ...      0.014000     -0.019500
# 75%        0.448975      0.476875  ...      0.461275      0.438650
# max        3.365000      3.915000  ...      3.111000      3.805000
#
# [8 rows x 100 columns]

# %%
c.T['mean'].hist(bins=50)

# %%
c.T['min'].hist(bins=50)

# %%
sns.boxplot(x = 'g-0',data = dados)

# %%
sns.boxplot(x = 'g-0',y = 'tratamento',data = dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x = 'tratamento',y = 'g-0',data = dados)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'], normalize =  'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'],dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados2 = dados[['g-0','g-3']]
dados2
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x = 'g-0',y = 'g-3',data = dados2)

# %%
sns.lmplot(x = 'g-0',y = 'g-3',data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x = 'g-0',y = 'g-8',data = dados,line_kws={'color' : 'red'},col='tratamento',row='tempo')

# %% [markdown]
# Vale salientar, que mesmo que os parametros g-0 e g-8 estejam muito correlacionados, não podemos atribuir uma relação de causalidade entre eles, ou seja, não é por que um está aumentando que o outro está decrescendo, mesmo que aparente no gráfico.

# %% [markdown]
# A análise desse gráfico destaca que quanto maior o tempo de tratamento mais inclinado está a linha, logo a droga está fazendo mais efeito, quanto maior o tempo

# %%
dados.loc[:,'g-0':'g-71']
# Out:
#           g-0     g-1     g-2     g-3  ...    g-68    g-69    g-70    g-71
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  0.6551 -0.7395 -0.7047 -0.5369
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.4054  0.1197  0.1956  0.0720
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.5916  0.6809  0.7821  0.6801
# 3     -0.5138 -0.2491 -0.2656  0.5288  ...  1.5370  0.3868 -0.4038  0.9767
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -0.1556 -0.5436  0.8585  0.5801
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ... -0.4539  1.5720  0.4938 -0.0538
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  1.5890  0.5003 -0.5807 -0.0282
# 23811  0.3942  0.3756  0.3109 -0.7389  ...  0.0860 -0.4175 -0.4059  0.0181
# 23812  0.6660  0.2324  0.4392  0.2044  ... -0.5875 -0.0457 -0.5292 -1.0270
# 23813 -0.8598  1.0240 -0.1361  0.7952  ...  0.5267 -2.4060 -0.3186 -0.9862
#
# [23814 rows x 72 columns]

# %%
dados.loc[:,'g-0':'g-71'].corr()
# Out:
#            g-0       g-1       g-2  ...      g-69      g-70      g-71
# g-0   1.000000  0.086032  0.176188  ...  0.226192 -0.411117 -0.108916
# g-1   0.086032  1.000000 -0.054518  ... -0.115127  0.043924 -0.146851
# g-2   0.176188 -0.054518  1.000000  ...  0.099248 -0.121961 -0.000929
# g-3   0.011266 -0.027855  0.042633  ...  0.051048 -0.150679 -0.071811
# g-4   0.403153  0.193647  0.013968  ...  0.085298 -0.166065 -0.003956
# ...        ...       ...       ...  ...       ...       ...       ...
# g-67 -0.565075 -0.009744 -0.153966  ... -0.203555  0.436629 -0.057973
# g-68  0.473076  0.115366  0.102565  ...  0.118543 -0.353177 -0.017930
# g-69  0.226192 -0.115127  0.099248  ...  1.000000 -0.189148  0.079328
# g-70 -0.411117  0.043924 -0.121961  ... -0.189148  1.000000  0.054151
# g-71 -0.108916 -0.146851 -0.000929  ...  0.079328  0.054151  1.000000
#
# [72 rows x 72 columns]

# %% [markdown]
# Nessa matriz de correlação, se caso os valores entre uma variavel e outra forem próximos de 1 ou -1, significa que essas variáveis são altamente correlacionadas, se caso forem próximas de 0, não são correlacionadas

# %%
import numpy as np
corr = dados.loc[:,'g-0':'g-50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()
mask = np.triu(np.ones_like(corr_celular, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_result = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_result.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Nas colunas observamos os diferentes tipos de mecanismos de ação da droga, lista nas linhas pelo ID.

# %%
dados_result['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_result['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# O 1 ou 0 corresponde a ativação ou a não ativação do mecanismo de ação pelo gene

# %%
dados_result['acetylcholine_receptor_agonist'].sum()
# Out:
# 190

# %%
total = dados_result.select_dtypes('int64').sum()
total
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %%
total = dados_result.drop('id',axis = 1).sum()
total
# Out:
# 5-alpha_reductase_inhibitor               17
# 11-beta-hsd1_inhibitor                    18
# acat_inhibitor                            24
# acetylcholine_receptor_agonist           190
# acetylcholine_receptor_antagonist        301
#                                         ...
# ubiquitin_specific_protease_inhibitor      6
# vegfr_inhibitor                          170
# vitamin_b                                 26
# vitamin_d_receptor_agonist                39
# wnt_inhibitor                             30
# Length: 206, dtype: int64

# %% [markdown]
# Nos 2 códigos acima, são formas diferentes de fazer a soma das colunas, desconsiderando a 1 coluna que tem resultados do tipo string e não inteiros.

# %%
dados_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
total.sort_values(ascending = False)
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# Curiosidade: O inibidor NFKB é um mecanismo utilizado geralmente em drogas cancerígenas

# %%
dados_result.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
dados_result.drop('id',axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_result.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_result['n_moa'] = dados_result.drop('id',axis = 1).sum(axis = 1)

# %%
dados_result['ativo_moa'] = (dados_result['n_moa'] != 0)
dados_result.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_result[['id','n_moa','ativo_moa']], on = 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# "on" corresponde à coluna da nossa tabela que está presente nas duas tabelas que vamos fazer o merge

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 288e0d205       1
# b3f24a171       1
# 122c63321       1
# 8d320a8c7       1
# 161572520       1
# Name: composto, Length: 3289, dtype: int64

# %%
compostos_principais = dados_combinados['composto'].value_counts().index[:5]
compostos_principais
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @compostos_principais'), y = 'g-0', x = 'composto', hue='ativo_moa')

# %% [markdown]
# O composto cacb2b860 é um composto utilizados nos grupos de controle, por isso ele é sempre falso.

# %% [markdown]
# ##Aula 4 - Desafios
#
# ###**Desafio 1: Encontrar o top10 das ações do MOA (inibidor, antagonista,..)**
#
# ###**Desafio 2: Criar a coluna eh_controle para quando a linha tratamento == com_controle**
#
# ###**Desafio 3: Criar 3 colunas eh_24, eh_48, eh_72 para quando a linha tempo ==24 ou ==48 ou ==72**
#
# ###**Desafio 4: Estudar sobe combinações de DF: (merge no pandas)**
#
# ###**Desafio 5: Fazer análise mais detalhada, considerando tempo e dose, para comparar as distribuições**
#
# ###**Desafio 6: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa um moa.**
#
# ###**Desafio 7: Descobrir se temos algum composto que dependendo da configuração do experimento, ativa um MOAs diferentes.**
#
# ###**Desafio 8: Resumo**

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_result.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64') ## Entrada do modelo
y = dados_combinados['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y, test_size = 0.2,stratify = y,random_state=598451)

modelo_rlogistica = LogisticRegression(max_iter =1000)
modelo_rlogistica.fit(x, y)
modelo_rlogistica.score(x_teste,y_teste)
# Out:
# 0.6674364896073903

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino,y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste,previsao_dummy)
# Out:
# 0.6067604450976275

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64') ## Entrada do modelo
y = dados_combinados['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y, test_size = 0.2,stratify = y,random_state=598451)

teste = []
treino = []
for i in range(1,15): 
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino,y_treino)
  teste.append(modelo_arvore.score(x_teste,y_teste))
  treino.append(modelo_arvore.score(x_treino,y_treino))

print(teste)
print(treino)
# Out:
# [0.6067604450976275, 0.6067604450976275, 0.6243963888305689, 0.6225068234306109, 0.626285954230527, 0.630065085030443, 0.6290153264749108, 0.6193575477640143, 0.6237665336972497, 0.6208272097417594, 0.6187276926306949, 0.6174679823640563, 0.6023514591643921, 0.5912240184757506]
# [0.6066348223190384, 0.6066348223190384, 0.6183927352894861, 0.6268437352369954, 0.6361345861109653, 0.6456878903994541, 0.6578132381502283, 0.6698860952180988, 0.6869980578447326, 0.7007506167655241, 0.7205396042202509, 0.7445278463072804, 0.7709831504907879, 0.7944989764316833]

# %%
sns.lineplot(x = range(1,15), y = teste, label='teste')
sns.lineplot(x = range(1,15), y = treino, label='treino')

# %% [markdown]
# Aconteceu um overfit, sendo uma das soluções criar uma random forest

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize = (15, 10), facecolor = 'k')
tree.plot_tree(modelo_arvore,
               ax = ax,
               fontsize = 10,
               rounded = True,
               filled = True,
               feature_names = x_treino.columns,
               class_names=['Não ativado','Ativado'])

plt.show()

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['dose','tempo', 'tratamento',])
# Out:
#                  id   composto  ...  tratamento_com_controle  tratamento_com_droga
# 0      id_000644bb2  b68db1d53  ...                        0                     1
# 1      id_000779bfc  df89a8e5a  ...                        0                     1
# 2      id_000a6266a  18bb41b2c  ...                        0                     1
# 3      id_0015fd391  8c7f86626  ...                        0                     1
# 4      id_001626bd3  7cbed3131  ...                        0                     1
# ...             ...        ...  ...                      ...                   ...
# 23809  id_fffb1ceed  df1d0a5a1  ...                        0                     1
# 23810  id_fffb70c0c  ecf3b6b74  ...                        0                     1
# 23811  id_fffc1c3f4  cacb2b860  ...                        1                     0
# 23812  id_fffcb9e7c  8b87a7a83  ...                        0                     1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id','n_moa','ativo_moa','composto'], axis = 1)
x = pd.get_dummies(x, columns=['dose','tempo', 'tratamento',])
y = dados_combinados['ativo_moa']
x_treino,x_teste,y_treino,y_teste = train_test_split(x,y, test_size = 0.2,stratify = y,random_state=598451)

modelo_random_forest = RandomForestClassifier()
modelo_random_forest.fit(x_treino,y_treino)
modelo_random_forest.score(x_teste,y_teste)
# Out:
# 0.6909510812513122

# %% [markdown]
# ##Aula 5:
#
# ###**Desafio 01: Tentar outros modelos, ou mudar os parametros dos modelos testados em aula**
#
# ###**Desafio 02: Estudar a documentação do sklearn**
#
# ###**Desafio 03: Estudar o fluxograma "Escolhendo o melhor modelo"**
#
# ###**Desafio 04: Testar outras perguntas de classificação**
#
# ###**Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever essa label.**
#
# ###**Desafio 06: Resuma o aprendizado**
